# %%
import pandas as pd
import numpy as np 
import math 
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
dp = pd.read_csv('train.csv')

# %%
dp[dp['Embarked'] == 'S']['Survived'].value_counts().plot(kind = 'bar')
plt.show()
print('S Survived Rate:',np.count_nonzero(dp[dp['Embarked'] == 'S']['Survived'])/ len(dp[dp['Embarked'] == 'S']))
# Out:
# S Survived Rate: 0.33695652173913043

# %%
dp[dp['Embarked'] == 'C']['Survived'].value_counts().plot(kind = 'bar')
plt.show()
print('C Survived Rate:',np.count_nonzero(dp[dp['Embarked'] == 'C']['Survived'])/ len(dp[dp['Embarked'] == 'C']))
# Out:
# C Survived Rate: 0.5535714285714286

# %%
dp[dp['Embarked'] == 'Q']['Survived'].value_counts().plot(kind = 'bar')
plt.show()
print('Q Survived Rate:',np.count_nonzero(dp[dp['Embarked'] == 'Q']['Survived'])/ len(dp[dp['Embarked'] == 'Q']))
# Out:
# Q Survived Rate: 0.38961038961038963

# %%
dp['Survived'].value_counts().plot(kind = 'bar')
plt.show()
print('Overall Survived Rate:',np.count_nonzero(dp['Survived'])/ len(dp['Survived']))
# Out:
# Overall Survived Rate: 0.3838383838383838

# %%
dp[dp['Fare'] <= 17]['Survived'].value_counts().plot(kind = 'bar')
plt.show()
print('Fare_0 Survived Rate:',np.count_nonzero(dp[dp['Fare'] <= 17]['Survived'])/ len(dp[dp['Fare'] <= 17]))
# Out:
# Overall Survived Rate: 0.2661290322580645

# %%
dp[dp['Fare'] > 17 & (dp['Fare'] <= 30)]['Survived'].value_counts().plot(kind = 'bar')
plt.show()
print('Fare_1 Survived Rate:',np.count_nonzero(dp[dp['Fare'] > 17 & (dp['Fare'] <= 30)]['Survived'])/ len(dp[dp['Fare'] > 17 & (dp['Fare'] <= 30)]))
# Out:
# Fare_1 Survived Rate: 0.3892694063926941

# %%
dp[dp['Fare'] > 30 & (dp['Fare'] <= 100)]['Survived'].value_counts().plot(kind = 'bar')
plt.show()
print('Fare_2 Survived Rate:',np.count_nonzero(dp[dp['Fare'] > 30 & (dp['Fare'] <= 100)]['Survived'])/ len(dp[dp['Fare'] > 30 & (dp['Fare'] <= 100)]))
# Out:
# Fare_2 Survived Rate: 0.3892694063926941

# %%
dp[dp['Fare'] > 100]['Survived'].value_counts().plot(kind = 'bar')
plt.show()
print('Fare_3 Survived Rate:',np.count_nonzero(dp[dp['Fare'] > 100 ]['Survived'])/ len(dp[dp['Fare'] > 100]))
# Out:
# Fare_3 Survived Rate: 0.7358490566037735

# %%
dp[dp['Survived'] == 1]['SibSp'].value_counts().plot(kind = 'bar')
plt.show()

# %%
dp[dp['Survived'] == 0]['SibSp'].value_counts().plot(kind = 'bar')
plt.show()

# %%
dp['SibSp'].value_counts().plot(kind = 'bar')
plt.show()

# %%
dp[dp['Survived'] == 1]['Age'].value_counts().sort_index().plot(kind = 'bar')
plt.show()
# Out:
# pandas.core.series.Series

# %%
dp[dp['Survived'] == 0]['Age'].value_counts().sort_index().plot(kind = 'bar')
plt.show()

# %%
dp['Age'].value_counts().sort_index().plot(kind = 'bar')
plt.show()

# %%
dp['Parch'].value_counts().sort_index().plot(kind = 'bar')
plt.show()

# %%
dp[dp['Survived'] == 0]['Parch'].value_counts().sort_index().plot(kind = 'bar')
plt.show()

# %%
dp[dp['Survived'] == 1]['Parch'].value_counts().sort_index().plot(kind = 'bar')
plt.show()

# %%
# using feature extraction to convert Name into a new feature called 'Titles'
dp['Titles'] = dp['Name'].str.extract(' ([A-Za-z]+)\.', expand= False)
# we created a new feature called Titles: Mr: 0; Miss: 1; Mrs: 2; Others: 3
titles_mapping = {'Mr': 0, 'Miss': 1, 'Mrs':2}
dp['Titles'] = dp['Titles'].map(titles_mapping)
dp['Titles'] = dp['Titles'].fillna(3)

# %%
dp[dp['Titles'] == 0]['Survived'].value_counts().sort_index().plot(kind = 'bar')
plt.show()

# %%
dp[dp['Titles'] == 1]['Survived'].value_counts().sort_index().plot(kind = 'bar')
plt.show()

# %%
dp[dp['Titles'] == 2]['Survived'].value_counts().sort_index().plot(kind = 'bar')
plt.show()

# %%
dp[dp['Titles'] == 3]['Survived'].value_counts().sort_index().plot(kind = 'bar')
plt.show()
